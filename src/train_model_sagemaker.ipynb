# %%
import sagemaker
from sagemaker.inputs import TrainingInput
from sagemaker.xgboost import XGBoost

# Automatically get the notebook's IAM role
role = sagemaker.get_execution_role()

# S3 paths
train_s3 = "s3://ml-pipeline-project-aniolmg/data/titanic_data.csv"
output_s3 = "s3://ml-pipeline-project-aniolmg/models/"

# %%
# Define XGBoost estimator
xgb_estimator = XGBoost(
    entry_point="train_model.py",
    role=role,
    instance_count=1,              # only one instance
    instance_type="ml.m5.large",   # sufficient for Titanic dataset
    framework_version="1.7-1",
    py_version="py3",
    output_path=output_s3,
    hyperparameters={
        "max_depth": 8,
        "eta": 0.3,
        "objective": "binary:logistic",
        "num_round": 200
    }
)

# Launch training job
xgb_estimator.fit({"train": TrainingInput(train_s3, content_type="csv")})
# Out:
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2025-09-29-17-49-41-765
# 2025-09-29 17:49:46 Starting - Starting the training job...
# 2025-09-29 17:50:01 Starting - Preparing the instances for training...
# 2025-09-29 17:50:19 Downloading - Downloading input data...
# 2025-09-29 17:51:01 Failed - Training job failed
# ..
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:19                                                                                   │
# │                                                                                                  │
# │   16 )                                                                                           │
# │   17                                                                                             │
# │   18 # Launch training job                                                                       │
# │ ❱ 19 xgb_estimator.fit({"train": TrainingInput(train_s3, content_type="csv")})                   │
# │   20                                                                                             │
# │                                                                                                  │
# │ /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/telemetry/telemetry │
# │ _logging.py:168 in wrapper                                                                       │
# │                                                                                                  │
# │   165 │   │   │   │   │   caught_ex = e                                                          │
# │   166 │   │   │   │   finally:                                                                   │
# │   167 │   │   │   │   │   if caught_ex:                                                          │
# │ ❱ 168 │   │   │   │   │   │   raise caught_ex                                                    │
# │   169 │   │   │   │   │   return response  # pylint: disable=W0150                               │
# │   170 │   │   │   else:                                                                          │
# │   171 │   │   │   │   logger.debug(                                                              │
# │                                                                                                  │
# │ /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/telemetry/telemetry │
# │ _logging.py:139 in wrapper                                                                       │
# │                                                                                                  │
# │   136 │   │   │   │   start_timer = perf_counter()                                               │
# │   137 │   │   │   │   try:                                                                       │
# │   138 │   │   │   │   │   # Call the original function                                           │
# │ ❱ 139 │   │   │   │   │   response = func(*args, **kwargs)                                       │
# │   140 │   │   │   │   │   stop_timer = perf_counter()                                            │
# │   141 │   │   │   │   │   elapsed = stop_timer - start_timer                                     │
# │   142 │   │   │   │   │   extra += f"&x-latency={round(elapsed, 2)}"                             │
# │                                                                                                  │
# │ /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/workflow/pipeline_c │
# │ ontext.py:346 in wrapper                                                                         │
# │                                                                                                  │
# │   343 │   │   │                                                                                  │
# │   344 │   │   │   return _StepArguments(retrieve_caller_name(self_instance), run_func, *args,    │
# │   345 │   │                                                                                      │
# │ ❱ 346 │   │   return run_func(*args, **kwargs)                                                   │
# │   347 │                                                                                          │
# │   348 │   return wrapper                                                                         │
# │   349                                                                                            │
# │                                                                                                  │
# │ /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/estimator.py:1429   │
# │ in fit                                                                                           │
# │                                                                                                  │
# │   1426 │   │   │   wait = True                                                                   │
# │   1427 │   │   │   forward_to_mlflow_tracking_server = True                                      │
# │   1428 │   │   if wait:                                                                          │
# │ ❱ 1429 │   │   │   self.latest_training_job.wait(logs=logs)                                      │
# │   1430 │   │   try:                                                                              │
# │   1431 │   │   │   if forward_to_mlflow_tracking_server:                                         │
# │   1432 │   │   │   │   from sagemaker.mlflow.forward_sagemaker_metrics import log_sagemaker_job  │
# │                                                                                                  │
# │ /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/estimator.py:2824   │
# │ in wait                                                                                          │
# │                                                                                                  │
# │   2821 │   │   │   logs = log_string_map[logs]                                                   │
# │   2822 │   │   # If logs are requested, call logs_for_jobs.                                      │
# │   2823 │   │   if logs != "None":                                                                │
# │ ❱ 2824 │   │   │   self.sagemaker_session.logs_for_job(self.job_name, wait=True, log_type=logs)  │
# │   2825 │   │   else:                                                                             │
# │   2826 │   │   │   self.sagemaker_session.wait_for_job(self.job_name)                            │
# │   2827                                                                                           │
# │                                                                                                  │
# │ /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/session.py:6375 in  │
# │ logs_for_job                                                                                     │
# │                                                                                                  │
# │   6372 │   │   │   exceptions.CapacityError: If the training job fails with CapacityError.       │
# │   6373 │   │   │   exceptions.UnexpectedStatusException: If waiting and the training job fails.  │
# │   6374 │   │   """                                                                               │
# │ ❱ 6375 │   │   _logs_for_job(self, job_name, wait, poll, log_type, timeout)                      │
# │   6376 │                                                                                         │
# │   6377 │   def logs_for_processing_job(self, job_name, wait=False, poll=10):                     │
# │   6378 │   │   """Display logs for a given processing job, optionally tailing them until the is  │
# │                                                                                                  │
# │ /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/session.py:8988 in  │
# │ _logs_for_job                                                                                    │
# │                                                                                                  │
# │   8985 │   │   │   │   last_profiler_rule_statuses = profiler_rule_statuses                      │
# │   8986 │                                                                                         │
# │   8987 │   if wait:                                                                              │
# │ ❱ 8988 │   │   _check_job_status(job_name, description, "TrainingJobStatus")                     │
# │   8989 │   │   if dot:                                                                           │
# │   8990 │   │   │   print()                                                                       │
# │   8991 │   │   # Customers are not billed for hardware provisioning, so billable time is less t  │
# │                                                                                                  │
# │ /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/session.py:9052 in  │
# │ _check_job_status                                                                                │
# │                                                                                                  │
# │   9049 │   │   │   │   allowed_statuses=["Completed", "Stopped"],                                │
# │   9050 │   │   │   │   actual_status=status,                                                     │
# │   9051 │   │   │   )                                                                             │
# │ ❱ 9052 │   │   raise exceptions.UnexpectedStatusException(                                       │
# │   9053 │   │   │   message=message,                                                              │
# │   9054 │   │   │   allowed_statuses=["Completed", "Stopped"],                                    │
# │   9055 │   │   │   actual_status=status,                                                         │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# UnexpectedStatusException: Error for Training job sagemaker-xgboost-2025-09-29-17-49-41-765: Failed. Reason:
# ClientError: Data download failed:Failed to download data. AccessDenied (403): User:
# arn:aws:sts::344809604964:assumed-role/sage-maker-full-acess-role/SageMaker is not authorized to perform:
# s3:GetObject on resource: "arn:aws:s3:::ml-pipeline-project-aniolmg/data/titanic_data.csv" because no
# identity-based policy allows the s3:GetObject action. Check troubleshooting guide for common errors:
# https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-python-sdk-troubleshooting.html
